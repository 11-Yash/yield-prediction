# %%
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('./'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./pesticides.csv
# ./rainfall.csv
# ./temp.csv
# ./Untitled.ipynb
# ./yield.csv
# ./yield_df.csv
# ./.ipynb_checkpoints\Untitled-checkpoint.ipynb

# %%
df = pd.read_csv('./pesticides.csv')

# %%
# df.head()
# df.info()
# df.describe()
# print(df.isnull().sum())
# for col in df.select_dtypes(include='object').columns:
#     print(f"Unique values in {col}:")
#     print(df[col].unique())
#     print()
# import matplotlib.pyplot as plt

# plt.boxplot(df['Value'])
# plt.show()
import pandas as pd
import numpy as np

def remove_extreme_values(df, column, lower_percentile=5, upper_percentile=95):
  """Removes extreme values from a column based on percentiles.

  Args:
    df: Pandas DataFrame.
    column: Name of the column to check for extreme values.
    lower_percentile: Lower percentile for outlier detection.
    upper_percentile: Upper percentile for outlier detection.

  Returns:
    Pandas DataFrame with extreme values removed.
  """

  lower_bound = df[column].quantile(lower_percentile / 100)
  upper_bound = df[column].quantile(upper_percentile / 100)
  df_filtered = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
  return df_filtered

# Example usage:
df = remove_extreme_values(df, 'Value')

# %%
def get_df_info(df):
    print("\n\033[1mShape of DataFrame:\033[0m ", df.shape)
    print("\n\033[1mColumns in DataFrame:\033[0m ", df.columns.to_list())
    print("\n\033[1mData types of columns:\033[0m\n", df.dtypes)
    
    print("\n\033[1mInformation about DataFrame:\033[0m")
    df.info()
    
    print("\n\033[1mNumber of unique values in each column:\033[0m")
    for col in df.columns:
        print(f"\033[1m{col}\033[0m: {df[col].nunique()}")
        
    print("\n\033[1mNumber of null (missing) values in each column:\033[0m\n", df.isnull().sum())
    
    print("\n\033[1mNumber of duplicate rows:\033[0m ", df.duplicated().sum())

# Call the function
get_df_info(df)
# Out:
# Shape of DataFrame:  (3360, 7)
#
# Columns in DataFrame:  ['Domain', 'Area', 'Element', 'Item', 'Year', 'Unit', 'Value']
#
# Data types of columns:
#  Domain      object
# Area        object
# Element     object
# Item        object
# Year         int64
# Unit        object
# Value      float64
# dtype: object
#
# Information about DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3360 entries, 0 to 4348
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Domain   3360 non-null   object
#  1   Area     3360 non-null   object
#  2   Element  3360 non-null   object
#  3   Item     3360 non-null   object
#  4   Year     3360 non-null   int64
#  5   Unit     3360 non-null   object
#  6   Value    3360 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 210.0+ KB
#
# Number of unique values in each column:
# Domain: 1
# Area: 143
# Element: 1
# Item: 1
# Year: 27
# Unit: 1
# Value: 2114
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns #pip install seaborn
import ipywidgets as widgets
from IPython.display import display

# Create dropdown
area_dropdown = widgets.Dropdown(options=df['Area'].unique(), description='Area:')

# Function to plot data
def plot_data(area):
    plt.figure(figsize=(10,6))
    temp_df = df[df['Area'] == area]
    plt.plot(temp_df['Year'], temp_df['Value'])
    plt.title(f'Pesticides Tonnes over the years in {area}')
    plt.xlabel('Year')
    plt.ylabel('Pesticides Tonnes')
    plt.grid(True)
    plt.show()

# Use interactive function to automatically update the plot
widgets.interactive(plot_data, area=area_dropdown)
# Out:
# interactive(children=(Dropdown(description='Area:', options=('Albania', 'Algeria', 'Angola', 'Antigua and Barb…

# %%
corr = df.corr(numeric_only = True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Heatmap of Correlations')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

# %%
# Here we separate and select our target variable
X = df.drop('Value', axis=1)
y = df['Value']

# %%
categorical_features = ['Domain','Area', 'Element','Item']
numerical_features = ['Year']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
encoder = OneHotEncoder(handle_unknown='ignore')
X_train_encoded = encoder.fit_transform(X_train[categorical_features])
X_test_encoded = encoder.transform(X_test[categorical_features])

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[numerical_features])
X_test_scaled = scaler.transform(X_test[numerical_features])

# %%
import scipy.sparse as sp
import numpy as np
X_train_preprocessed = sp.hstack((X_train_scaled, X_train_encoded))
X_test_preprocessed = sp.hstack((X_test_scaled, X_test_encoded))

# %%
model = DecisionTreeRegressor(random_state=101)
model.fit(X_train_preprocessed, y_train)
# Out:
# DecisionTreeRegressor(random_state=101)

# %%
y_pred = model.predict(X_test_preprocessed)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print evaluation metrics
print('Decision Tree:')
print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Error: {mae}')
print(f'R^2 Score: {r2}\n')
# Out:
# Decision Tree:
# Mean Squared Error: 629378.2040200894
# Mean Absolute Error: 246.7052827380952
# R^2 Score: 0.9245695118675962

# %%
import matplotlib.pyplot as plt

# Calculate residuals
residuals = y_test - y_pred

# Plot the distribution of residuals
plt.hist(residuals, bins=30)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np  # Assuming you have NumPy for index creation

# Assuming you have an index, replace this with your actual index
index = np.arange(len(y_test))

# Create a DataFrame for easier plotting
import pandas as pd
data = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred}, index=index)

# Plot the line graph
data.plot(figsize=(10, 6))
plt.title('Actual vs Predicted Values')
plt.xlabel('Index')
plt.ylabel('Value')
plt.legend()
plt.show()
